# %% [markdown]
# <a href="https://colab.research.google.com/github/Ductrinh01/AI_Exercises_CNN/blob/main/BT_11TienGiay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/Data_AI/Tien_Giay_VN/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'1000dong.'+str(i+1)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/Data_AI/Tien_Giay_VN/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('200dong'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500dong'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('1000dong'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('2000dong'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('5000dong'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('10000dong'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('20000dong'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('50000dong'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('100000dong'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('200000dong'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500000dong'):
    output = 10
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('11TienGiay_photos.npy', photos)
save('11TienGiay_labels.npy', labels)
# Out:
# (110, 200, 200, 3) (110,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi
from tensorflow.keras.optimizers import SGD

model = Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D((2, 2)),
    
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(64, activation='relu'),
    Dense(11, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
 history = model.fit(photos, labels, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 6s 1s/step - loss: 2925.3625 - accuracy: 0.0545
# Epoch 2/20
# 4/4 [==============================] - 5s 1s/step - loss: 1667.0743 - accuracy: 0.1091
# Epoch 3/20
# 4/4 [==============================] - 5s 1s/step - loss: 99.4274 - accuracy: 0.1636
# Epoch 4/20
# 4/4 [==============================] - 5s 1s/step - loss: 9.1370 - accuracy: 0.3091
# Epoch 5/20
# 4/4 [==============================] - 5s 1s/step - loss: 2.1564 - accuracy: 0.5727
# Epoch 6/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.8781 - accuracy: 0.7182
# Epoch 7/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.5709 - accuracy: 0.8909
# Epoch 8/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.2905 - accuracy: 0.9182
# Epoch 9/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.1646 - accuracy: 0.9545
# Epoch 10/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0806 - accuracy: 0.9909
# Epoch 11/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0359 - accuracy: 0.9909
# Epoch 12/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0275 - accuracy: 0.9909
# Epoch 13/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0320 - accuracy: 0.9909
# Epoch 14/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0679 - accuracy: 0.9909
# Epoch 15/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.1700 - accuracy: 0.9818
# Epoch 16/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.1124 - accuracy: 0.9727
# Epoch 17/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0783 - accuracy: 0.9818
# Epoch 18/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0282 - accuracy: 0.9909
# Epoch 19/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.1866 - accuracy: 0.9909
# Epoch 20/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0581 - accuracy: 0.9909

# %%
model.evaluate(photos,labels)
# Out:
# 4/4 [==============================] - 2s 344ms/step - loss: 0.0027 - accuracy: 1.0000
# [0.0026540940161794424, 1.0]

# %%
model.save('11TienGiay_Final.h5')

# %%
from keras.models import load_model
models=load_model('11TienGiay_Final.h5')

# %%
classes = ["200dong","500dong","1000dong","2000dong","5000dong","10000dong","20000dong","50000dong","100000dong","200000dong","500000dong"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('20k.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09127583 0.08848726 0.09251542 0.09176201 0.09111048 0.08935367
#   0.09259911 0.09025093 0.0919378  0.0903578  0.09034971]]
# '20000dong'
