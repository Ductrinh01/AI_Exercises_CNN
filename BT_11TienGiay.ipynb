# %% [markdown]
# <a href="https://colab.research.google.com/github/Ductrinh01/AI_Exercises_CNN/blob/main/BT_11TienGiay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/Data_AI/Tien_Giay_VN/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'1000dong.'+str(i+1)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/Data_AI/Tien_Giay_VN/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('200dong'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500dong'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('1000dong'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('2000dong'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('5000dong'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('10000dong'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('20000dong'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('50000dong'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('100000dong'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('200000dong'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500000dong'):
    output = 10
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('11TienGiay_photos.npy', photos)
save('11TienGiay_labels.npy', labels)
# Out:
# (110, 200, 200, 3) (110,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(11, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
 history = model.fit(photos, labels, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 49ms/step - loss: 6222.9014 - accuracy: 0.0636
# Epoch 2/50
# 4/4 [==============================] - 0s 39ms/step - loss: 1286.7042 - accuracy: 0.1273
# Epoch 3/50
# 4/4 [==============================] - 0s 37ms/step - loss: 127.5767 - accuracy: 0.1545
# Epoch 4/50
# 4/4 [==============================] - 0s 38ms/step - loss: 17.4118 - accuracy: 0.2455
# Epoch 5/50
# 4/4 [==============================] - 0s 38ms/step - loss: 2.9546 - accuracy: 0.2727
# Epoch 6/50
# 4/4 [==============================] - 0s 37ms/step - loss: 1.8798 - accuracy: 0.3636
# Epoch 7/50
# 4/4 [==============================] - 0s 37ms/step - loss: 1.4629 - accuracy: 0.5091
# Epoch 8/50
# 4/4 [==============================] - 0s 39ms/step - loss: 1.2910 - accuracy: 0.5364
# Epoch 9/50
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1702 - accuracy: 0.5909
# Epoch 10/50
# 4/4 [==============================] - 0s 38ms/step - loss: 1.0254 - accuracy: 0.6182
# Epoch 11/50
# 4/4 [==============================] - 0s 36ms/step - loss: 0.9016 - accuracy: 0.7091
# Epoch 12/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7001 - accuracy: 0.7364
# Epoch 13/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.5171 - accuracy: 0.8455
# Epoch 14/50
# 4/4 [==============================] - 0s 39ms/step - loss: 0.7347 - accuracy: 0.7364
# Epoch 15/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.7162 - accuracy: 0.7636
# Epoch 16/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4817 - accuracy: 0.8364
# Epoch 17/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3397 - accuracy: 0.8909
# Epoch 18/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1969 - accuracy: 0.9364
# Epoch 19/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3702 - accuracy: 0.9000
# Epoch 20/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1926 - accuracy: 0.9545
# Epoch 21/50
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1408 - accuracy: 0.9818
# Epoch 22/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2216 - accuracy: 0.9636
# Epoch 23/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1147 - accuracy: 0.9545
# Epoch 24/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 25/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0302 - accuracy: 0.9909
# Epoch 26/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0634 - accuracy: 0.9909
# Epoch 27/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 28/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0193 - accuracy: 0.9909
# Epoch 35/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0416 - accuracy: 0.9909
# Epoch 38/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0343 - accuracy: 0.9909
# Epoch 39/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0678 - accuracy: 0.9909
# Epoch 41/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0255 - accuracy: 0.9909
# Epoch 43/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0171 - accuracy: 0.9909
# Epoch 46/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0010 - accuracy: 1.0000

# %%
model.evaluate(photos,labels)
# Out:
# 4/4 [==============================] - 0s 22ms/step - loss: 7.3031e-04 - accuracy: 1.0000
# [0.0007303057936951518, 1.0]

# %%
model.save('11TienGiay_Final.h5')

# %%
from keras.models import load_model
models=load_model('11TienGiay_Final.h5')

# %%
classes = ["200dong","500dong","1000dong","2000dong","5000dong","10000dong","20000dong","50000dong","100000dong","200000dong","500000dong"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('../content/drive/MyDrive/Data_AI/Tien_Giay_VN/500000dong.1.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09094103 0.09190767 0.08874973 0.08930448 0.08876088 0.08900754
#   0.09409846 0.0848058  0.09105566 0.09202152 0.09934723]]
# '500000dong'
